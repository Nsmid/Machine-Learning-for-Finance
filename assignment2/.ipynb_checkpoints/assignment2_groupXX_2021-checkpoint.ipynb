# %% [markdown]
# # Assignment 2 -- ML4F 2021
#
# ## Instructions
#
# * Each group submits _only one_ notebook via canvas on the assignment page.
# * The notebook should be named `assignment2_groupXX.ipynb` where `XX` is your group number,
# e.g. for group 3 this will be `assignment2_group03.ipynb`.
# * The notebook should run without raising any errors.
# * We recommend keeping the folder structure
# ```
# assignment/
#     data/
#     lib/
#     assignment2_groupXX.ipynb
# ```
# * We strongly recommend git, as you are encouraged to collaborate and split up the work and maybe even start independently. To see how to set up your own repo for your group, see `L2-git-slides.pdf`.
# * Do not spend time on optimizing the speed of your code.
# * We strongly encourage you to experiment, try different approaches and combinations and get to know the problem from alternative angles. But the final notebook should only contain the necessary results for grading.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing
from sklearn.pipeline import Pipeline
from scipy.stats.mstats import winsorize
from scipy.stats import mstats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## Introduction

# %% [markdown]
# The Paycheck Protection Program (PPP) gives support to companies who are negatively impacted by Covid-19 to pay their employees. Many businesses have been affected and the money was limited. This means the PPP cannot give all the companies money. The dataset provided contains the loans to different companies. It also contains the probability of default (`ProbabilityDefault`) as estimated by the loan officer.

# %% [markdown]
# Let's load and have a look at the data.

# %%
path = os.path.join('data','loans.xlsx')

df_data = pd.read_excel(path)
df_data.head(10)
# Out:
#   LoanAmount         City State    Zip  NAICSCode  \
# 0      20800        EAGLE    ID  83616   531210.0
# 1      80000       HAYDEN    ID  83835   722511.0
# 2      75500  IDAHO FALLS    ID  83401   811121.0
# 3     133500   POST FALLS    ID  83854   722211.0
# 4       8187        RIGBY    ID  83442   327991.0
# 5      16700     MERIDIAN    ID  83642   621330.0
# 6      26900       MOSCOW    ID  83843   621310.0
# 7      40600  IDAHO FALLS    ID  83402   722513.0
# 8      58767     LEWISTON    ID  83501   811111.0
# 9      46000        BOISE    ID  83706   524210.0
#
#                       BusinessType RaceEthnicity        Gender      Veteran  \
# 0  Limited  Liability Company(LLC)    Unanswered    Unanswered   Unanswered
# 1                      Corporation         Asian  Female Owned   Unanswered
# 2         Subchapter S Corporation         White    Male Owned  Non-Veteran
# 3  Limited  Liability Company(LLC)         White    Unanswered   Unanswered
# 4              Sole Proprietorship         White    Male Owned  Non-Veteran
# 5  Limited  Liability Company(LLC)    Unanswered  Female Owned  Non-Veteran
# 6    Limited Liability Partnership    Unanswered    Unanswered   Unanswered
# 7  Limited  Liability Company(LLC)    Unanswered    Unanswered   Unanswered
# 8  Limited  Liability Company(LLC)    Unanswered    Unanswered   Unanswered
# 9         Subchapter S Corporation    Unanswered    Unanswered   Unanswered
#
#   NonProfit  JobsRetained         DateApproved  \
# 0       NaN           0.0  2020-07-04 00:00:00
# 1       NaN          24.0           04/15/2020
# 2       NaN           7.0  2020-10-04 00:00:00
# 3       NaN          26.0           04/13/2020
# 4       NaN           1.0  2020-05-05 00:00:00
# 5       NaN           0.0           04/28/2020
# 6       NaN           2.0  2020-08-06 00:00:00
# 7       NaN           0.0           04/28/2020
# 8       NaN           4.0  2020-03-05 00:00:00
# 9       NaN           4.0  2020-12-04 00:00:00
#
#                             Lender       CD  AgeLoan  ProbabilityDefault
# 0            Washington Trust Bank  ID - 01      117            1.250967
# 1                     Glacier Bank  ID - 01      230            6.033691
# 2                    Bank of Idaho  ID - 02      236            2.334621
# 3            First Interstate Bank  ID - 01      240            9.567953
# 4                      Beehive FCU  ID - 02       51            1.462785
# 5                 Idaho Central CU  ID - 01      121            8.855862
# 6        Zions Bank, A Division of  ID - 01      144            3.322314
# 7                 Idaho Central CU  ID - 02      182            4.111426
# 8  U.S. Bank, National Association  ID - 01      211            5.022466
# 9     KeyBank National Association  ID - 02      199            4.404192

# %% [markdown]
# # Question 1
# (12 points)

# %% [markdown]
# Use the methods discussed so far to preprocess the data. Make some descriptive statistics and histograms etc to find out more about the distributions of the data. Are there NaNs, outliers etc? Then choose what preprocessing to apply and clearly explain your choices.

# %%
df_data.dtypes
# Out:
# LoanAmount             object
# City                   object
# State                  object
# Zip                     int64
# NAICSCode             float64
# BusinessType           object
# RaceEthnicity          object
# Gender                 object
# Veteran                object
# NonProfit              object
# JobsRetained          float64
# DateApproved           object
# Lender                 object
# CD                     object
# AgeLoan                 int64
# ProbabilityDefault    float64
# dtype: object

# %%
df_data['LoanAmount'] = pd.to_numeric(df_data['LoanAmount'],errors='coerce')

# %%
df_data.hist(figsize=(30,30))
# Out:
# array([[<AxesSubplot:title={'center':'LoanAmount'}>,
#         <AxesSubplot:title={'center':'Zip'}>],
#        [<AxesSubplot:title={'center':'NAICSCode'}>,
#         <AxesSubplot:title={'center':'JobsRetained'}>],
#        [<AxesSubplot:title={'center':'AgeLoan'}>,
#         <AxesSubplot:title={'center':'ProbabilityDefault'}>]],
#       dtype=object)

# %%
stats = pd.DataFrame(df_data.describe(include='all'))
stats
# Out:
#            LoanAmount   City  State           Zip      NAICSCode  \
# count    26852.000000  26855  26855  26855.000000   26333.000000
# unique            NaN    352      1           NaN            NaN
# top               NaN  BOISE     ID           NaN            NaN
# freq              NaN   4949  26855           NaN            NaN
# mean     32639.463601    NaN    NaN  83573.683076  510319.572400
# std      33270.802106    NaN    NaN    309.367113  203553.540773
# min         52.000000    NaN    NaN  59847.000000  111110.000000
# 25%       8847.500000    NaN    NaN  83402.000000  423110.000000
# 50%      20143.210000    NaN    NaN  83642.000000  532412.000000
# 75%      44800.000000    NaN    NaN  83706.000000  621399.000000
# max     149925.000000    NaN    NaN  99128.000000  999990.000000
#
#                            BusinessType RaceEthnicity      Gender     Veteran  \
# count                             26838         26855       26855       26855
# unique                               15             6           3           3
# top     Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# freq                              11049         24308       21450       22872
# mean                                NaN           NaN         NaN         NaN
# std                                 NaN           NaN         NaN         NaN
# min                                 NaN           NaN         NaN         NaN
# 25%                                 NaN           NaN         NaN         NaN
# 50%                                 NaN           NaN         NaN         NaN
# 75%                                 NaN           NaN         NaN         NaN
# max                                 NaN           NaN         NaN         NaN
#
#        NonProfit  JobsRetained DateApproved            Lender       CD  \
# count        517  25780.000000        26855             26855    26855
# unique         1           NaN           77               289        4
# top            Y           NaN   04/28/2020  Idaho Central CU  ID - 01
# freq         517           NaN         3577              3617    14370
# mean         NaN      5.651862          NaN               NaN      NaN
# std          NaN     15.293767          NaN               NaN      NaN
# min          NaN      0.000000          NaN               NaN      NaN
# 25%          NaN      0.000000          NaN               NaN      NaN
# 50%          NaN      2.000000          NaN               NaN      NaN
# 75%          NaN      6.000000          NaN               NaN      NaN
# max          NaN    500.000000          NaN               NaN      NaN
#
#              AgeLoan  ProbabilityDefault
# count   26855.000000        26855.000000
# unique           NaN                 NaN
# top              NaN                 NaN
# freq             NaN                 NaN
# mean      124.983132            3.244025
# std        72.430690            3.821607
# min         0.000000           -7.566606
# 25%        62.000000            1.558186
# 50%       125.000000            2.732590
# 75%       188.000000            4.342069
# max       250.000000          500.707550

# %%
df_data = df_data.fillna(df_data.mean())

# %%
df_data
# Out:
#        LoanAmount         City State    Zip  NAICSCode  \
# 0         20800.0        EAGLE    ID  83616   531210.0
# 1         80000.0       HAYDEN    ID  83835   722511.0
# 2         75500.0  IDAHO FALLS    ID  83401   811121.0
# 3        133500.0   POST FALLS    ID  83854   722211.0
# 4          8187.0        RIGBY    ID  83442   327991.0
# ...           ...          ...   ...    ...        ...
# 26850     59000.0        BOISE    ID  83704   484210.0
# 26851      9400.0       ASHTON    ID  83420   111998.0
# 26852     30000.0         BUHL    ID  83316   445120.0
# 26853     13394.0     SHOSHONE    ID  83352   541320.0
# 26854    148582.0     MERIDIAN    ID  83642   722511.0
#
#                           BusinessType RaceEthnicity        Gender  \
# 0      Limited  Liability Company(LLC)    Unanswered    Unanswered
# 1                          Corporation         Asian  Female Owned
# 2             Subchapter S Corporation         White    Male Owned
# 3      Limited  Liability Company(LLC)         White    Unanswered
# 4                  Sole Proprietorship         White    Male Owned
# ...                                ...           ...           ...
# 26850                      Corporation    Unanswered    Unanswered
# 26851              Sole Proprietorship    Unanswered    Unanswered
# 26852         Subchapter S Corporation         White    Male Owned
# 26853                      Corporation    Unanswered    Unanswered
# 26854         Subchapter S Corporation    Unanswered    Male Owned
#
#            Veteran NonProfit  JobsRetained         DateApproved  \
# 0       Unanswered       NaN           0.0  2020-07-04 00:00:00
# 1       Unanswered       NaN          24.0           04/15/2020
# 2      Non-Veteran       NaN           7.0  2020-10-04 00:00:00
# 3       Unanswered       NaN          26.0           04/13/2020
# 4      Non-Veteran       NaN           1.0  2020-05-05 00:00:00
# ...            ...       ...           ...                  ...
# 26850   Unanswered       NaN          10.0  2020-10-04 00:00:00
# 26851   Unanswered       NaN           4.0           04/28/2020
# 26852  Non-Veteran       NaN          13.0  2020-07-04 00:00:00
# 26853   Unanswered       NaN           0.0  2020-08-05 00:00:00
# 26854  Non-Veteran       NaN          50.0  2020-10-04 00:00:00
#
#                                        Lender       CD  AgeLoan  \
# 0                       Washington Trust Bank  ID - 01      117
# 1                                Glacier Bank  ID - 01      230
# 2                               Bank of Idaho  ID - 02      236
# 3                       First Interstate Bank  ID - 01      240
# 4                                 Beehive FCU  ID - 02       51
# ...                                       ...      ...      ...
# 26850                    Mountain America FCU  ID - 02      234
# 26851                           Bank of Idaho  ID - 02       69
# 26852                            Farmers Bank  ID - 02      154
# 26853  Wells Fargo Bank, National Association  ID - 02       97
# 26854                   First Interstate Bank  ID - 01      230
#
#        ProbabilityDefault
# 0                1.250967
# 1                6.033691
# 2                2.334621
# 3                9.567953
# 4                1.462785
# ...                   ...
# 26850            5.031729
# 26851            2.508476
# 26852            3.521201
# 26853            2.170813
# 26854           13.206022
#
# [26855 rows x 16 columns]

# %%
df_data_w = df_data[['JobsRetained','ProbabilityDefault']]

# %%
def using_mstats_df(df):
    return df.apply(using_mstats, axis=0)

def using_mstats(s):
    return mstats.winsorize(s, limits=[0.05, 0.05])

# %%
df_data[['JobsRetained','ProbabilityDefault']] = using_mstats_df(df_data_w)

# %%
stats2 = pd.DataFrame(df_data.describe(include='all'))
stats2
# Out:
#            LoanAmount   City  State           Zip      NAICSCode  \
# count    26855.000000  26855  26855  26855.000000   26855.000000
# unique            NaN    352      1           NaN            NaN
# top               NaN  BOISE     ID           NaN            NaN
# freq              NaN   4949  26855           NaN            NaN
# mean     32639.463601    NaN    NaN  83573.683076  510319.572400
# std      33268.943627    NaN    NaN    309.367113  201565.449866
# min         52.000000    NaN    NaN  59847.000000  111110.000000
# 25%       8852.500000    NaN    NaN  83402.000000  423450.000000
# 50%      20150.000000    NaN    NaN  83642.000000  531320.000000
# 75%      44800.000000    NaN    NaN  83706.000000  621340.000000
# max     149925.000000    NaN    NaN  99128.000000  999990.000000
#
#                            BusinessType RaceEthnicity      Gender     Veteran  \
# count                             26838         26855       26855       26855
# unique                               15             6           3           3
# top     Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# freq                              11049         24308       21450       22872
# mean                                NaN           NaN         NaN         NaN
# std                                 NaN           NaN         NaN         NaN
# min                                 NaN           NaN         NaN         NaN
# 25%                                 NaN           NaN         NaN         NaN
# 50%                                 NaN           NaN         NaN         NaN
# 75%                                 NaN           NaN         NaN         NaN
# max                                 NaN           NaN         NaN         NaN
#
#        NonProfit  JobsRetained DateApproved            Lender       CD  \
# count        517  26855.000000        26855             26855    26855
# unique         1           NaN           77               289        4
# top            Y           NaN   04/28/2020  Idaho Central CU  ID - 01
# freq         517           NaN         3577              3617    14370
# mean         NaN      4.390793          NaN               NaN      NaN
# std          NaN      5.245464          NaN               NaN      NaN
# min          NaN      0.000000          NaN               NaN      NaN
# 25%          NaN      1.000000          NaN               NaN      NaN
# 50%          NaN      2.000000          NaN               NaN      NaN
# 75%          NaN      6.000000          NaN               NaN      NaN
# max          NaN     19.000000          NaN               NaN      NaN
#
#              AgeLoan  ProbabilityDefault
# count   26855.000000        26855.000000
# unique           NaN                 NaN
# top              NaN                 NaN
# freq             NaN                 NaN
# mean      124.983132            3.146705
# std        72.430690            1.982385
# min         0.000000            0.571267
# 25%        62.000000            1.558186
# 50%       125.000000            2.732590
# 75%       188.000000            4.342069
# max       250.000000            7.637512

# %%
df_data_norm = df_data[['LoanAmount','Zip','ProbabilityDefault','AgeLoan']]

# %%
df_data[['LoanAmount','Zip','ProbabilityDefault','AgeLoan']] = preprocessing.normalize(df_data_norm, norm='l2')

# %%
stats3 = pd.DataFrame(df_data.describe(include='all'))
stats3
# Out:
#           LoanAmount   City  State           Zip      NAICSCode  \
# count   26855.000000  26855  26855  26855.000000   26855.000000
# unique           NaN    352      1           NaN            NaN
# top              NaN  BOISE     ID           NaN            NaN
# freq             NaN   4949  26855           NaN            NaN
# mean        0.306678    NaN    NaN      0.911822  510319.572400
# std         0.242680    NaN    NaN      0.125047  201565.449866
# min         0.000620    NaN    NaN      0.381969  111110.000000
# 25%         0.105365    NaN    NaN      0.881181  423450.000000
# 50%         0.234369    NaN    NaN      0.972147  531320.000000
# 75%         0.472775    NaN    NaN      0.994433  621340.000000
# max         0.924174    NaN    NaN      1.000000  999990.000000
#
#                            BusinessType RaceEthnicity      Gender     Veteran  \
# count                             26838         26855       26855       26855
# unique                               15             6           3           3
# top     Limited  Liability Company(LLC)    Unanswered  Unanswered  Unanswered
# freq                              11049         24308       21450       22872
# mean                                NaN           NaN         NaN         NaN
# std                                 NaN           NaN         NaN         NaN
# min                                 NaN           NaN         NaN         NaN
# 25%                                 NaN           NaN         NaN         NaN
# 50%                                 NaN           NaN         NaN         NaN
# 75%                                 NaN           NaN         NaN         NaN
# max                                 NaN           NaN         NaN         NaN
#
#        NonProfit  JobsRetained DateApproved            Lender       CD  \
# count        517  26855.000000        26855             26855    26855
# unique         1           NaN           77               289        4
# top            Y           NaN   04/28/2020  Idaho Central CU  ID - 01
# freq         517           NaN         3577              3617    14370
# mean         NaN      4.390793          NaN               NaN      NaN
# std          NaN      5.245464          NaN               NaN      NaN
# min          NaN      0.000000          NaN               NaN      NaN
# 25%          NaN      1.000000          NaN               NaN      NaN
# 50%          NaN      2.000000          NaN               NaN      NaN
# 75%          NaN      6.000000          NaN               NaN      NaN
# max          NaN     19.000000          NaN               NaN      NaN
#
#              AgeLoan  ProbabilityDefault
# count   26855.000000        26855.000000
# unique           NaN                 NaN
# top              NaN                 NaN
# freq             NaN                 NaN
# mean        0.001275            0.000032
# std         0.000631            0.000017
# min         0.000000            0.000003
# 25%         0.000738            0.000018
# 50%         0.001446            0.000031
# 75%         0.001834            0.000046
# max         0.002323            0.000092

# %%
df_data.hist(figsize=(30,30))
# Out:
# array([[<AxesSubplot:title={'center':'LoanAmount'}>,
#         <AxesSubplot:title={'center':'Zip'}>],
#        [<AxesSubplot:title={'center':'NAICSCode'}>,
#         <AxesSubplot:title={'center':'JobsRetained'}>],
#        [<AxesSubplot:title={'center':'AgeLoan'}>,
#         <AxesSubplot:title={'center':'ProbabilityDefault'}>]],
#       dtype=object)

# %% [markdown]
# # Question 2
# (22 points)

# %% [markdown]
# Explain what a k-means model is.

# %% [markdown]
# - identifies k number of centroids, and then allocates every data point to the nearest cluster, while keeping the centroids as small as possible.
# ---- COPIED---

# %% [markdown]
# Estimate a k-means model with 3 clusters for the variables `LoanAmount`, `Zip`, `ProbabilityDefault` and `AgeLoan`.

# %%
df_data_kmeans=df_data[['LoanAmount', 'Zip', 'ProbabilityDefault', 'AgeLoan']]

# %%
Kmean = KMeans(n_clusters=3, random_state=25)

# %%
Kmean.fit(df_data_kmeans)
# Out:
# KMeans(n_clusters=3, random_state=25)

# %%
Kmean.cluster_centers_
# Out:
# array([[7.34661309e-01, 6.67199335e-01, 4.70286262e-05, 1.80734153e-03],
#        [1.31594211e-01, 9.88379051e-01, 2.37695940e-05, 8.57214994e-04],
#        [4.23287245e-01, 9.00484486e-01, 4.12235734e-05, 1.89213384e-03]])

# %%
y_kmeans=Kmean.predict(df_data_kmeans)

# %% [markdown]
# Determine with the elbow method with inertia what the right number of clusters is. Please plot the inertia and explain your choice of clusters.

# %%
inertia_list = []
for num_clusters in range(1, 10):
    kmeans_model = KMeans(n_clusters=num_clusters, init="k-means++")
    kmeans_model.fit(df_data_kmeans)
    inertia_list.append(kmeans_model.inertia_)

# %%
plt.plot(range(1,10),inertia_list)
plt.scatter(range(1,10),inertia_list)
plt.scatter(3, inertia_list[3], marker="X", s=300, c="r")
plt.xlabel("Number of Clusters", size=13)
plt.ylabel("Inertia Value", size=13)
plt.title("Different Inertia Values for Different Number of Clusters", size=17)
# Out:
# Text(0.5, 1.0, 'Different Inertia Values for Different Number of Clusters')

# %%
Kmean.labels_
# Out:
# array([1, 0, 0, ..., 2, 1, 0], dtype=int32)

# %%
silhouette_score = silhouette_score(df_data_kmeans, Kmean.labels_)
silhouette_score
# Out:
# 0.6239857122156088

# %%
silhouette_list = []
for i in range(1, 10):
    kmeans_model = KMeans(n_clusters=i, init="k-means++", random_state=25)
    label = kmeans_model.labels_
    silhouette_score = silhouette_score(df_data_kmeans, label)
    silhouette_list.append(silhouette_score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-c357c42d272e> in <module>
#       2 for i in range(1, 10):
#       3     kmeans_model = KMeans(n_clusters=i, init="k-means++", random_state=25)
# ----> 4     label = kmeans_model.labels_
#       5     silhouette_score = silhouette_score(df_data_kmeans, label)
#       6     silhouette_list.append(silhouette_score)
#
# AttributeError: 'KMeans' object has no attribute 'labels_'

# %%
silhouette_list = []
for i in range(1, 10):
    silhouette_model = silhouette_score(n_clusters=num_clusters, init="k-means++")
    silhouette_model.fit(df_data_kmeans)
    silhouette_list.append(silhouette_model.inertia_)

# %% [markdown]
# Do the same but this time using the silhouette score. Compare both. Would you now reconsider your choice of the previous question?

# %%
for i in range(1,10):
   
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(df_data_kmeans)

# %% [markdown]
# # Question 3
#
# (22 points)
#
# Mention one advantage and one disadvantage of using Principal Component Analysis (PCA).

# %%
## Your answer

# %% [markdown]
# Reduce the dataset to two dimensions with PCA and make a clear plot. Make sure to label all the important information.

# %%
## Your answer

# %% [markdown]
# This time reduce the dataset to two dimensions with t-SNE and make a clear plot.

# %%
## Your answer

# %% [markdown]
# Explain whether PCA or t-SNE is better to use with this particular data set.

# %%
# Your answer

# %% [markdown]
# # Question 4
#
# (22 points)
#
# Add the two columns you made with PCA to the dataset. Then pick a Decision Tree model and train a good model to predict the Probability of Default (`ProbabilityDefault`). It is not necessary to tune the hyperparameters (so the default settings are fine).

# %%
## Your answer

# %% [markdown]
# Explain how well your model performs. Do you think the predictions are any good?

# %%
## Your answer

# %% [markdown]
# # Question 5
#
# (22 points)
#
# This question turns on how to tune hyperparameters. Please compute what you consider the best choice for "splitter", "max_depth", and "min_samples_leaf" (jointly).

# %%
## Your answer

# %% [markdown]
# Does your hyperparameter tuning does lead to overfitting? Provide arguments.

# %%
## Your answer

# %% [markdown]
# Explain whether you consider the hyperparameter tuning useful (given amongst others the compute time, precision, other considerations, etc.).

# %%
## Your answer

# %% [markdown]
# ---
